# %%
import requests

url = "https://ec.europa.eu/eurostat/statistics-explained/SEPDF/cache/6776.pdf"
local_path = "/Workspace/Users/danibgc@gmail.com/databricks-demos/gender_pay_gap.pdf"

with open(local_path, "wb") as f:
    f.write(requests.get(url).content)

print("Downloaded successfully")
